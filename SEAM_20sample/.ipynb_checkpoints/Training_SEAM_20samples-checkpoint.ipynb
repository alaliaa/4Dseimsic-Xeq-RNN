# %%
# %matplotlib inline

import matplotlib.pyplot as plt
from prep_data import Dataset 
from torch.utils.data import DataLoader
from LSTM_Net import LSTM_Net 
import torch.nn as nn 
import torch 
import numpy as np
import math 
import random
import gc
import time 
from skimage.transform import resize
from util import * 
from torch.optim.lr_scheduler import ReduceLROnPlateau
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import MinMaxScaler, StandardScaler
import os,sys


from torch.utils.tensorboard import SummaryWriter

# %% [markdown]
# ### SEED for reproducability

# %%
torch.backends.cudnn.deterministic = True
random.seed(1)
np.random.seed(1)
torch.manual_seed(1)
torch.cuda.manual_seed(1)

# %%
## GPU 
os.environ["CUDA_VISIBLE_DEVICES"]= '2'

# %% [markdown]
# ## Global variables

# %%
# data paths and parameters
data_path = '../LSTM_Otway_submitted_v2/data'
base_path = f"{data_path}/base_otw.npy" 
mon_path = f"{data_path}/mon_otw.npy" 

parm = {
 'nt': 1250,
 'ng': 605,
 'ns': 121,
 'dt': 0.002,
 'dg': 0.004000000189989805,
 'ds': 1.0,
 'ot': 0.0,
 'og': 0.012000000104308128,
 'os': 0.0}


# Hyperparameters for training
batchsz = 32 
num_epochs = 100 
LR = 0.002
hsz = 100
act = 'tanh'
n_layer=1
bias= True
dropout = 0.


# define the overburden window 
# start= 100 
# last = 650 

feature_length=21

# # define the overburden window 
start = 450
last =  650 

epoch=0

hyperpar = f"_lr{LR}_nlayer{n_layer}_act{act}_bias{bias}_batchsz{batchsz}_time_start{start}_end{last}"

net_path = "./Network/"

# -----------------------------------------------#
# RSF PATH 
# path = '/home/alaliaa/Time_lapse_ML/ML_Models2/data/'
# base = path + 'Base_data.rsf'
# mon = path + 'MonNoisy_data.rsf'

# %%
base = np.load(base_path)
mon = np.load(mon_path)
 
ns,ng,nt = base.shape
print ('ns',ns,'ng',ng,'nt',nt)

# # Take only few shots 
# base = base[30:50,]
# mon = mon[30:50,]
# ns,ng,nt_ = base.shape

# Take only few shots 
base = base[50:70:2,]
mon = mon[50:70:2,]
ns,ng,nt_ = base.shape


base = base.reshape((ns*ng,nt))
mon = mon.reshape((ns*ng,nt))

print('data shapeed to 2d',base.shape)
# Out:
# ns 120 ng 609 nt 1250
# data shapeed to 2d (6090, 1250)

# %%
skip=3
base = base[::skip,]
mon = mon[::skip,]
print(f"data shape after slipping {skip} traces: {base.shape}")
# Out:
# data shape after slipping 3 traces: (2030, 1250)

# %%
def Plot_shot(data,par):
    vmin, vmax = np.percentile(data, [2,98])
    plt.figure(figsize=(15,8))
    plt.imshow(data[0*ng:10*ng,:].T, aspect='auto',
           vmin=vmin, vmax=vmax,cmap='gray',extent=[par['og'],par['dg']*par['ng']+par['og'],
                                                    par['nt']*par['dt']+par['ot'],par['ot']])
    plt.ylabel('Time (s)')
    plt.xlabel('Distance (km)')

# This plot 2D concatenated shots 
Plot_shot(base-mon,parm)

# %%
''' Pre Processing the data for trainign 
    - specify the overburden time window 
    - split the data into training and testing 
    - scale the data 

'''

def scale_data(data=None):
    print('shape of data that will be scaled', data.shape)
    assert len(data.shape)==2
    ng,nt = data.shape  
    
    data = data.T
    scaler= MinMaxScaler(feature_range=(-1,1))
    # scaler= StandardScaler()
    scaler.fit(data)
    scaled_data = scaler.transform(data)
    scaled_data = scaled_data.T 


    return scaled_data,scaler
         




 
base = base[:,start:last]
base = base[~np.all(base==0 , axis=1)] # this exclude the zero traces 
mon = mon[:,start:last]   
mon = mon[~np.all(mon==0 , axis=1)] # this exclude the zero traces 


# split data 
test_size = 0.2
# base_train,base_test,mon_train,mon_test  =  train_test_split(base,mon,test_size=test_size,shuffle=True)
base_train = base[:,:150]
mon_train = mon[:,:150]
base_test = base[:,150:]
mon_test = mon[:,150:]



Ntrain = base_train.shape[0]
Ntest = base_test.shape[0]



# scaling
base_train, base_train_scaler = scale_data(base_train) 
mon_train , mon_train_scaler  = scale_data(mon_train) 
base_test , base_test_scaler  = scale_data(base_test) 
mon_test  , mon_test_scaler   = scale_data(mon_test) 


# move to torch 
base_train = torch.from_numpy(base_train).double()
mon_train  = torch.from_numpy(mon_train).double()
base_test  = torch.from_numpy(base_test).double()
mon_test   = torch.from_numpy(mon_test).double()
# Out:
# shape of data that will be scaled (2030, 150)
# shape of data that will be scaled (2030, 150)
# shape of data that will be scaled (2030, 50)
# shape of data that will be scaled (2030, 50)

# %%
def Plot_shot(data,par):
    vmin, vmax = np.percentile(data, [2,98])
    plt.figure(figsize=(15,8))
    plt.imshow(data[0*ng:10*ng,:].T, aspect='auto',
           vmin=vmin, vmax=vmax,cmap='gray',extent=[par['og'],par['dg']*par['ng']+par['og'],
                                                    par['nt']*par['dt']+par['ot'],par['ot']])
    plt.ylabel('Time (s)')
    plt.xlabel('Distance (km)')

# This plot 2D concatenated shots 
Plot_shot(base,parm)

# %% [markdown]
# # Prepare input window

# %%
def window (x,dimension=-1,size=11,step=1):
    ''' x has to be pytorch tensor'''
    return x.unfold(dimension,size,step)


print(base_train.shape)
base_train_win =window(base_train,size=feature_length,step=1)
mon_train_win =window(mon_train,size=feature_length,step=1)[:,:,feature_length//2]
mon_train_win = mon_train_win.view(mon_train_win.shape[0],mon_train_win.shape[1],-1)

base_test_win =window(base_test,size=feature_length,step=1)
mon_test_win =window(mon_test,size=feature_length,step=1)[:,:,feature_length//2]
mon_test_win = mon_test_win.view(mon_test_win.shape[0],mon_test_win.shape[1],-1)


print(base_train_win.shape),print(mon_train_win.shape)
print(base_test_win.shape),print(mon_test_win.shape)
# Out:
# torch.Size([2030, 150])
# torch.Size([2030, 130, 21])
# torch.Size([2030, 130, 1])
# torch.Size([2030, 30, 21])
# torch.Size([2030, 30, 1])
# (None, None)

# %%
# Prepare the data to be trained 
training_data = Dataset(base_train_win,mon_train_win)
testing_data = Dataset(base_test_win,mon_test_win)

train_loader= DataLoader (dataset=training_data,batch_size=batchsz,shuffle=True)
test_loader= DataLoader(dataset=testing_data,batch_size=batchsz,shuffle=True)

# to see the batch that are loaded 
# next(iter(data_loader)) ?

# %%
# Set up network and 

model = LSTM_Net(input_size=base_train_win.shape[-1], hidden_layer_size=hsz, 
                output_size=mon_train_win.shape[-1],
                batch_sz=batchsz,num_lstm_layer=n_layer,activation=act,dropout=dropout,bias=bias)
# model = LSTM_Net2(1,hsz,1,batchsz)
model = model.double()
model.cuda()
criterion = nn.MSELoss()
optimizer = torch.optim.Adam(model.parameters(),lr=LR)
# optimizer = torch.optim.Adam(model.parameters(),lr=LR,weight_decay=1e-7)
scheduler = ReduceLROnPlateau(optimizer,'min',verbose=True,patience=10,factor=0.1)
loss_arr=[]
loss_arr_test=[]
R2_train = []
R2_test = []
grad_norm = [] 

print(f"number of training samples {Ntrain} and validation sample {Ntest}")
# Out:
# number of training samples 2030 and validation sample 2030

# %%
# for i_test,loader_test in enumerate(test_loader,0):
#     inp, label = loader_test

#     plt.imshow(label[:,:,-1].numpy().T)
#     plt.axis('tight')
#     plt.colorbar()
#     plt.show()

# %%
# for i_test,loader_test in enumerate(train_loader,0):
#     inp, label = loader_test

#     plt.imshow(label[:,:,-1].numpy().T)
#     plt.axis('tight')
#     plt.colorbar()
#     plt.show()

# %%
# Training loop 

start_time = time.time()
writer = SummaryWriter()

for epoch in range (num_epochs):
        epoch_loss = 0
        R2_train_running=0
        total_norm =0
        # loop over batches
        for i, loader, in enumerate(train_loader,0):
            optimizer.zero_grad()
            inputs, labels = loader
            inputs = inputs.cuda()
            labels = labels.cuda()
            if inputs.shape[0]!= batchsz: break
            model.h_init() # reset the hidden state for new series  
            inputs = inputs.view(inputs.shape[0],inputs.shape[1],-1)
            labels = labels.view(labels.shape[0],labels.shape[1],-1)
            y_pred = model(inputs)
            batch_loss = criterion(y_pred,labels)
            R2_train_running += r2_score(target=labels,prediction=y_pred)
            epoch_loss +=  batch_loss.item()
            batch_loss.backward()
            model.hidden_cell[0].detach_()
            model.hidden_cell[1].detach_()
            # Gradient clipping to avoid exploding problem 
            # torch.nn.utils.clip_grad_norm_(model.parameters(),max_norm=2,norm_type=2)

            optimizer.step()
            for p in model.parameters():
                param_norm = p.grad.detach().data.norm(2)
                total_norm += param_norm.item() ** 2
            total_norm += total_norm ** 0.5
            
        total_norm = total_norm/(i+1)    
        epoch_loss = epoch_loss / (i+1) # average by the number batch loops 
        R2_train_running = R2_train_running / (i+1) # average by the number batch loops 
  
        with   torch.no_grad():
            epoch_loss_test =0
            R2_test_running=0
            for i_test,loader_test in enumerate(test_loader,0):
                test_inp, test_label = loader_test
                if test_inp.shape[0]!= batchsz: break
                model.h_init()
                x_test = test_inp.cuda()
                y_test = test_label.cuda()  
                x_test = x_test.view(x_test.shape[0],x_test.shape[1],-1)
                y_test = y_test.view(y_test.shape[0],y_test.shape[1],-1)   
                test_pred = model(x_test)
                test_loss = criterion(test_pred,y_test)
                R2_test_running += r2_score(target = y_test,prediction = test_pred)
                epoch_loss_test += test_loss.item()
                # R2_test_running += R2
        epoch_loss_test = epoch_loss_test/ (i_test+1) # average by the number batch loops 
        R2_test_running = R2_test_running/  (i_test+1) # average by the number batch loops 
        scheduler.step(epoch_loss_test)  # this should reduce LR on plateau
        grad_norm.append(total_norm)
        loss_arr.append(epoch_loss)
        loss_arr_test.append(epoch_loss_test)
        R2_train.append(R2_train_running)
        R2_test.append(R2_test_running)
        print(f'epoch: {epoch+1:3}/{num_epochs:3}  Training_loss: {epoch_loss:.5e} Validation_loss: {epoch_loss_test:.5e} \n R2 training: {R2_train_running:.2} R2 test: {R2_test_running:.2}')

        if epoch%5 ==0 : torch.save(model.state_dict(),f'{net_path}LSTM_Otway_epc{epoch}{hyperpar}.pth')

        writer.add_scalar('Loss/train', epoch_loss, epoch)
        writer.add_scalar('Loss/test',epoch_loss_test, epoch)
        writer.add_scalar('grad_norm',total_norm, epoch)

        

end_time = time.time()
# Out:
# epoch:   1/100  Training_loss: 6.37822e-03 Validation_loss: 1.49287e-02
#  R2 training: 0.96 R2 test: 0.94
# epoch:   2/100  Training_loss: 4.85892e-03 Validation_loss: 1.31443e-02
#  R2 training: 0.96 R2 test: 0.94
# epoch:   3/100  Training_loss: 4.49964e-03 Validation_loss: 1.24725e-02
#  R2 training: 0.96 R2 test: 0.95
# epoch:   4/100  Training_loss: 4.26158e-03 Validation_loss: 1.17106e-02
#  R2 training: 0.96 R2 test: 0.95
# epoch:   5/100  Training_loss: 4.12669e-03 Validation_loss: 1.16329e-02
#  R2 training: 0.97 R2 test: 0.95
# epoch:   6/100  Training_loss: 3.97203e-03 Validation_loss: 1.13658e-02
#  R2 training: 0.97 R2 test: 0.95
# epoch:   7/100  Training_loss: 3.81503e-03 Validation_loss: 1.11845e-02
#  R2 training: 0.97 R2 test: 0.95
# epoch:   8/100  Training_loss: 3.84687e-03 Validation_loss: 1.09204e-02
#  R2 training: 0.97 R2 test: 0.95
# epoch:   9/100  Training_loss: 3.64725e-03 Validation_loss: 1.06477e-02
#  R2 training: 0.97 R2 test: 0.95
# epoch:  10/100  Training_loss: 3.68407e-03 Validation_loss: 1.01015e-02
#  R2 training: 0.97 R2 test: 0.95
# epoch:  11/100  Training_loss: 3.54970e-03 Validation_loss: 1.03503e-02
#  R2 training: 0.97 R2 test: 0.95
# epoch:  12/100  Training_loss: 3.56150e-03 Validation_loss: 1.01876e-02
#  R2 training: 0.97 R2 test: 0.95
# epoch:  13/100  Training_loss: 3.49734e-03 Validation_loss: 1.03360e-02
#  R2 training: 0.97 R2 test: 0.95
# epoch:  14/100  Training_loss: 3.44162e-03 Validation_loss: 1.07529e-02
#  R2 training: 0.97 R2 test: 0.95
# epoch:  15/100  Training_loss: 3.41310e-03 Validation_loss: 1.01830e-02
#  R2 training: 0.97 R2 test: 0.95
# epoch:  16/100  Training_loss: 3.42987e-03 Validation_loss: 1.05207e-02
#  R2 training: 0.97 R2 test: 0.95
# epoch:  17/100  Training_loss: 3.50076e-03 Validation_loss: 1.00558e-02
#  R2 training: 0.97 R2 test: 0.95
# epoch:  18/100  Training_loss: 3.31533e-03 Validation_loss: 1.01210e-02
#  R2 training: 0.97 R2 test: 0.95
# epoch:  19/100  Training_loss: 3.34683e-03 Validation_loss: 9.96828e-03
#  R2 training: 0.97 R2 test: 0.95
# epoch:  20/100  Training_loss: 3.26377e-03 Validation_loss: 9.89548e-03
#  R2 training: 0.97 R2 test: 0.95
# epoch:  21/100  Training_loss: 3.30377e-03 Validation_loss: 1.07904e-02
#  R2 training: 0.97 R2 test: 0.95
# epoch:  22/100  Training_loss: 3.20275e-03 Validation_loss: 9.84441e-03
#  R2 training: 0.97 R2 test: 0.95
# epoch:  23/100  Training_loss: 3.14620e-03 Validation_loss: 9.86978e-03
#  R2 training: 0.97 R2 test: 0.95
# epoch:  24/100  Training_loss: 3.14590e-03 Validation_loss: 9.84414e-03
#  R2 training: 0.97 R2 test: 0.95
# epoch:  25/100  Training_loss: 3.12924e-03 Validation_loss: 1.00711e-02
#  R2 training: 0.97 R2 test: 0.95
# epoch:  26/100  Training_loss: 3.11156e-03 Validation_loss: 9.81822e-03
#  R2 training: 0.97 R2 test: 0.95
# epoch:  27/100  Training_loss: 3.05456e-03 Validation_loss: 9.50521e-03
#  R2 training: 0.97 R2 test: 0.95
# epoch:  28/100  Training_loss: 2.95577e-03 Validation_loss: 9.30345e-03
#  R2 training: 0.97 R2 test: 0.96
# epoch:  29/100  Training_loss: 2.96396e-03 Validation_loss: 9.47396e-03
#  R2 training: 0.97 R2 test: 0.95
# epoch:  30/100  Training_loss: 2.89045e-03 Validation_loss: 9.71279e-03
#  R2 training: 0.97 R2 test: 0.95
# epoch:  31/100  Training_loss: 2.91772e-03 Validation_loss: 9.33651e-03
#  R2 training: 0.97 R2 test: 0.96
# epoch:  32/100  Training_loss: 2.84472e-03 Validation_loss: 9.82296e-03
#  R2 training: 0.97 R2 test: 0.95
# epoch:  33/100  Training_loss: 2.77412e-03 Validation_loss: 9.24482e-03
#  R2 training: 0.97 R2 test: 0.96
# epoch:  34/100  Training_loss: 2.79055e-03 Validation_loss: 9.78348e-03
#  R2 training: 0.97 R2 test: 0.95
# epoch:  35/100  Training_loss: 2.76780e-03 Validation_loss: 9.46240e-03
#  R2 training: 0.97 R2 test: 0.95
# epoch:  36/100  Training_loss: 2.66342e-03 Validation_loss: 9.38182e-03
#  R2 training: 0.97 R2 test: 0.96
# epoch:  37/100  Training_loss: 2.70935e-03 Validation_loss: 9.27371e-03
#  R2 training: 0.97 R2 test: 0.96
# epoch:  38/100  Training_loss: 2.71391e-03 Validation_loss: 9.57616e-03
#  R2 training: 0.97 R2 test: 0.95
# epoch:  39/100  Training_loss: 2.66687e-03 Validation_loss: 9.87273e-03
#  R2 training: 0.97 R2 test: 0.95
# epoch:  40/100  Training_loss: 2.64781e-03 Validation_loss: 9.36270e-03
#  R2 training: 0.97 R2 test: 0.96
# epoch:  41/100  Training_loss: 2.53302e-03 Validation_loss: 9.45045e-03
#  R2 training: 0.97 R2 test: 0.95
# epoch:  42/100  Training_loss: 2.56217e-03 Validation_loss: 9.21570e-03
#  R2 training: 0.97 R2 test: 0.96
# epoch:  43/100  Training_loss: 2.50930e-03 Validation_loss: 9.27709e-03
#  R2 training: 0.97 R2 test: 0.96
# epoch:  44/100  Training_loss: 2.52537e-03 Validation_loss: 9.36258e-03
#  R2 training: 0.97 R2 test: 0.96
# epoch:  45/100  Training_loss: 2.49072e-03 Validation_loss: 9.34525e-03
#  R2 training: 0.97 R2 test: 0.96
# epoch:  46/100  Training_loss: 2.47469e-03 Validation_loss: 9.42959e-03
#  R2 training: 0.97 R2 test: 0.96
# epoch:  47/100  Training_loss: 2.44814e-03 Validation_loss: 9.40135e-03
#  R2 training: 0.97 R2 test: 0.95
# epoch:  48/100  Training_loss: 2.47246e-03 Validation_loss: 9.47760e-03
#  R2 training: 0.97 R2 test: 0.95
# epoch:  49/100  Training_loss: 2.42021e-03 Validation_loss: 9.27107e-03
#  R2 training: 0.97 R2 test: 0.96
# epoch:  50/100  Training_loss: 2.39483e-03 Validation_loss: 9.14831e-03
#  R2 training: 0.97 R2 test: 0.96
# epoch:  51/100  Training_loss: 2.35046e-03 Validation_loss: 9.40312e-03
#  R2 training: 0.97 R2 test: 0.96
# epoch:  52/100  Training_loss: 2.35523e-03 Validation_loss: 9.40074e-03
#  R2 training: 0.97 R2 test: 0.96
# epoch:  53/100  Training_loss: 2.33076e-03 Validation_loss: 9.39863e-03
#  R2 training: 0.97 R2 test: 0.96
# epoch:  54/100  Training_loss: 2.33332e-03 Validation_loss: 9.60681e-03
#  R2 training: 0.97 R2 test: 0.95
# epoch:  55/100  Training_loss: 2.28925e-03 Validation_loss: 9.30002e-03
#  R2 training: 0.97 R2 test: 0.96
# epoch:  56/100  Training_loss: 2.32065e-03 Validation_loss: 9.29346e-03
#  R2 training: 0.97 R2 test: 0.96
# epoch:  57/100  Training_loss: 2.24920e-03 Validation_loss: 9.14122e-03
#  R2 training: 0.97 R2 test: 0.96
# epoch:  58/100  Training_loss: 2.22395e-03 Validation_loss: 9.11689e-03
#  R2 training: 0.97 R2 test: 0.96
# epoch:  59/100  Training_loss: 2.23318e-03 Validation_loss: 9.56761e-03
#  R2 training: 0.97 R2 test: 0.95
# epoch:  60/100  Training_loss: 2.27743e-03 Validation_loss: 9.54856e-03
#  R2 training: 0.97 R2 test: 0.95
# epoch:  61/100  Training_loss: 2.19817e-03 Validation_loss: 9.49759e-03
#  R2 training: 0.97 R2 test: 0.95
# epoch:  62/100  Training_loss: 2.19491e-03 Validation_loss: 9.27505e-03
#  R2 training: 0.97 R2 test: 0.96
# epoch:  63/100  Training_loss: 2.21624e-03 Validation_loss: 9.28103e-03
#  R2 training: 0.97 R2 test: 0.96
# epoch:  64/100  Training_loss: 2.19213e-03 Validation_loss: 9.59382e-03
#  R2 training: 0.97 R2 test: 0.95
# epoch:  65/100  Training_loss: 2.14655e-03 Validation_loss: 9.31376e-03
#  R2 training: 0.97 R2 test: 0.96
# epoch:  66/100  Training_loss: 2.14041e-03 Validation_loss: 9.40901e-03
#  R2 training: 0.97 R2 test: 0.96
# epoch:  67/100  Training_loss: 2.14513e-03 Validation_loss: 9.58236e-03
#  R2 training: 0.97 R2 test: 0.95
# epoch:  68/100  Training_loss: 2.10973e-03 Validation_loss: 9.58747e-03
#  R2 training: 0.97 R2 test: 0.95
# Epoch    70: reducing learning rate of group 0 to 2.0000e-04.
# epoch:  69/100  Training_loss: 2.14157e-03 Validation_loss: 9.63002e-03
#  R2 training: 0.97 R2 test: 0.95
# epoch:  70/100  Training_loss: 1.95527e-03 Validation_loss: 9.44473e-03
#  R2 training: 0.98 R2 test: 0.96
# epoch:  71/100  Training_loss: 1.86613e-03 Validation_loss: 9.46968e-03
#  R2 training: 0.98 R2 test: 0.95
# epoch:  72/100  Training_loss: 1.84866e-03 Validation_loss: 9.45601e-03
#  R2 training: 0.98 R2 test: 0.95
# epoch:  73/100  Training_loss: 1.84374e-03 Validation_loss: 9.45182e-03
#  R2 training: 0.98 R2 test: 0.95
# epoch:  74/100  Training_loss: 1.83480e-03 Validation_loss: 9.52349e-03
#  R2 training: 0.98 R2 test: 0.95
# epoch:  75/100  Training_loss: 1.82899e-03 Validation_loss: 9.51969e-03
#  R2 training: 0.98 R2 test: 0.95
# epoch:  76/100  Training_loss: 1.81733e-03 Validation_loss: 9.50598e-03
#  R2 training: 0.98 R2 test: 0.95
# epoch:  77/100  Training_loss: 1.82352e-03 Validation_loss: 9.48089e-03
#  R2 training: 0.98 R2 test: 0.95
# epoch:  78/100  Training_loss: 1.81127e-03 Validation_loss: 9.52736e-03
#  R2 training: 0.98 R2 test: 0.95
# epoch:  79/100  Training_loss: 1.80547e-03 Validation_loss: 9.47672e-03
#  R2 training: 0.98 R2 test: 0.95
# Epoch    81: reducing learning rate of group 0 to 2.0000e-05.
# epoch:  80/100  Training_loss: 1.80385e-03 Validation_loss: 9.58412e-03
#  R2 training: 0.98 R2 test: 0.95
# epoch:  81/100  Training_loss: 1.77858e-03 Validation_loss: 9.56698e-03
#  R2 training: 0.98 R2 test: 0.95
# epoch:  82/100  Training_loss: 1.77339e-03 Validation_loss: 9.55373e-03
#  R2 training: 0.98 R2 test: 0.95
# epoch:  83/100  Training_loss: 1.77032e-03 Validation_loss: 9.57700e-03
#  R2 training: 0.98 R2 test: 0.95
# epoch:  84/100  Training_loss: 1.77047e-03 Validation_loss: 9.57583e-03
#  R2 training: 0.98 R2 test: 0.95
# epoch:  85/100  Training_loss: 1.76713e-03 Validation_loss: 9.57857e-03
#  R2 training: 0.98 R2 test: 0.95
# epoch:  86/100  Training_loss: 1.76754e-03 Validation_loss: 9.58277e-03
#  R2 training: 0.98 R2 test: 0.95
# epoch:  87/100  Training_loss: 1.76848e-03 Validation_loss: 9.61147e-03
#  R2 training: 0.98 R2 test: 0.95
# epoch:  88/100  Training_loss: 1.76610e-03 Validation_loss: 9.57621e-03
#  R2 training: 0.98 R2 test: 0.95
# epoch:  89/100  Training_loss: 1.77088e-03 Validation_loss: 9.59253e-03
#  R2 training: 0.98 R2 test: 0.95
# epoch:  90/100  Training_loss: 1.75766e-03 Validation_loss: 9.53321e-03
#  R2 training: 0.98 R2 test: 0.95
# Epoch    92: reducing learning rate of group 0 to 2.0000e-06.
# epoch:  91/100  Training_loss: 1.76443e-03 Validation_loss: 9.59123e-03
#  R2 training: 0.98 R2 test: 0.95
# epoch:  92/100  Training_loss: 1.76444e-03 Validation_loss: 9.57007e-03
#  R2 training: 0.98 R2 test: 0.95
# epoch:  93/100  Training_loss: 1.76446e-03 Validation_loss: 9.58076e-03
#  R2 training: 0.98 R2 test: 0.95
# epoch:  94/100  Training_loss: 1.75449e-03 Validation_loss: 9.58505e-03
#  R2 training: 0.98 R2 test: 0.95
# epoch:  95/100  Training_loss: 1.76221e-03 Validation_loss: 9.58039e-03
#  R2 training: 0.98 R2 test: 0.95
# epoch:  96/100  Training_loss: 1.76113e-03 Validation_loss: 9.57234e-03
#  R2 training: 0.98 R2 test: 0.95
# epoch:  97/100  Training_loss: 1.76105e-03 Validation_loss: 9.56116e-03
#  R2 training: 0.98 R2 test: 0.95
# epoch:  98/100  Training_loss: 1.76196e-03 Validation_loss: 9.57780e-03
#  R2 training: 0.98 R2 test: 0.95
# epoch:  99/100  Training_loss: 1.76164e-03 Validation_loss: 9.58759e-03
#  R2 training: 0.98 R2 test: 0.95
# epoch: 100/100  Training_loss: 1.76001e-03 Validation_loss: 9.55215e-03
#  R2 training: 0.98 R2 test: 0.95

# %%
print(f"Training time is  {(end_time-start_time)/60} min ")
# Out:
# Training time is  9.227564505736034 min

# %%
# saving the model 
# old net in './Network/LSTM_Otway.pth'

torch.save(model.state_dict(),f'{net_path}LSTM_Otway_epc{epoch}{hyperpar}.pth')

loss_arr = np.array(loss_arr)
loss_arr_test = np.array(loss_arr_test) 

np.save(f'./loss_arr/Training_loss_Otway{hyperpar}',loss_arr)
np.save(f'./loss_arr/Testing_loss_Otway{hyperpar}',loss_arr_test)
# np.save('./loss_arr/Training_R2_Otway',np.array(R2_train))
# np.save('./loss_arr/Testing_R2_Otway',np.array(R2_test))

plot_history(loss_arr,loss_arr_test,'Fig/loss_Otway{hyperpar}')


# plot_r2(R2_train,R2_test,'Fig/R2_Otway')
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# /tmp/ipykernel_18110/601406536.py in <module>
#      12 # np.save('./loss_arr/Testing_R2_Otway',np.array(R2_test))
#      13
# ---> 14 plot_history(loss_arr,loss_arr_test,'Fig/loss_Otway{hyperpar}')
#      15
#      16
#
# /tmp/ipykernel_18110/1138984597.py in plot_history(trainingloss, testingloss, netname)
#      20
#      21     name='./output/figure/Loss_'+netname+'.png'
# ---> 22     fig.savefig(name, bbox_inches='tight')
#
# ~/anaconda3/envs/pytorch_lstm_timelapse/lib/python3.9/site-packages/matplotlib/figure.py in savefig(self, fname, transparent, **kwargs)
#    3010                         ax.patch._cm_set(facecolor='none', edgecolor='none'))
#    3011
# -> 3012             self.canvas.print_figure(fname, **kwargs)
#    3013
#    3014     def ginput(self, n=1, timeout=30, show_clicks=True,
#
# ~/anaconda3/envs/pytorch_lstm_timelapse/lib/python3.9/site-packages/matplotlib/backend_bases.py in print_figure(self, filename, dpi, facecolor, edgecolor, orientation, format, bbox_inches, pad_inches, bbox_extra_artists, backend, **kwargs)
#    2312                 # force the figure dpi to 72), so we need to set it again here.
#    2313                 with cbook._setattr_cm(self.figure, dpi=dpi):
# -> 2314                     result = print_method(
#    2315                         filename,
#    2316                         facecolor=facecolor,
#
# ~/anaconda3/envs/pytorch_lstm_timelapse/lib/python3.9/site-packages/matplotlib/backend_bases.py in wrapper(*args, **kwargs)
#    1641             kwargs.pop(arg)
#    1642
# -> 1643         return func(*args, **kwargs)
#    1644
#    1645     return wrapper
#
# ~/anaconda3/envs/pytorch_lstm_timelapse/lib/python3.9/site-packages/matplotlib/_api/deprecation.py in wrapper(*inner_args, **inner_kwargs)
#     410                          else deprecation_addendum,
#     411                 **kwargs)
# --> 412         return func(*inner_args, **inner_kwargs)
#     413
#     414     DECORATORS[wrapper] = decorator
#
# ~/anaconda3/envs/pytorch_lstm_timelapse/lib/python3.9/site-packages/matplotlib/backends/backend_agg.py in print_png(self, filename_or_obj, metadata, pil_kwargs, *args)
#     539         """
#     540         FigureCanvasAgg.draw(self)
# --> 541         mpl.image.imsave(
#     542             filename_or_obj, self.buffer_rgba(), format="png", origin="upper",
#     543             dpi=self.figure.dpi, metadata=metadata, pil_kwargs=pil_kwargs)
#
# ~/anaconda3/envs/pytorch_lstm_timelapse/lib/python3.9/site-packages/matplotlib/image.py in imsave(fname, arr, vmin, vmax, cmap, format, origin, dpi, metadata, pil_kwargs)
#    1673         pil_kwargs.setdefault("format", format)
#    1674         pil_kwargs.setdefault("dpi", (dpi, dpi))
# -> 1675         image.save(fname, **pil_kwargs)
#    1676
#    1677
#
# ~/anaconda3/envs/pytorch_lstm_timelapse/lib/python3.9/site-packages/PIL/Image.py in save(self, fp, format, **params)
#    2235                 fp = builtins.open(filename, "r+b")
#    2236             else:
# -> 2237                 fp = builtins.open(filename, "w+b")
#    2238
#    2239         try:
#
# FileNotFoundError: [Errno 2] No such file or directory: './output/figure/Loss_Fig/loss_Otway{hyperpar}.png'

# %%
def plot_history(trainingloss,testingloss,netname):

    Epc = np.arange(1,trainingloss.shape[0]+1)
    fig, ax = plt.subplots(figsize=(8,4))

    ax.plot(trainingloss,color='b',label='Training')
    ax.plot(testingloss,color='r',label='Validation')

    ax.grid(which='both')
    ax.set_xlabel('Epochs', fontsize=16, fontweight='bold')
    ax.set_ylabel('Loss ',fontsize=16, fontweight='bold')

    ax.xaxis.set_major_formatter(FormatStrFormatter('%.0f'))
    ax.yaxis.set_major_formatter(FormatStrFormatter('%.0e'))

    ax.tick_params(axis='both',which='minor',labelsize=16)
    plt.xticks(fontsize=16,fontweight='semibold')
    plt.yticks(fontsize=16,fontweight='semibold')
    ax.legend(prop={'size': 16, 'weight':'bold'})

    name=netname+'.png'
    fig.savefig(name, bbox_inches='tight')

# %%
50
