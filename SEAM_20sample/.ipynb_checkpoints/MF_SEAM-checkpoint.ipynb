# %%
# %matplotlib inline
# %load_ext autoreload
# %autoreload 2
# from TL import preproc_TL 
import matplotlib.pyplot as plt
import torch.nn as nn 
import torch 
import numpy as np
import math 
import gc
import time 
import sys 



from time import sleep
import numpy as np
import scipy
import warnings
import pylops
warnings.filterwarnings("ignore")


from scipy.sparse.linalg import lsqr
from pylops.basicoperators import *
from pylops.signalprocessing import *
from pylops.optimization.leastsquares import *
from pylops.utils.wavelets import ricker
from pylops.utils.signalprocessing import *

# %%
# data paths and parameters
data_path = '../LSTM_SEAM_submitted_v2/data/'
base_path = f"{data_path}/base_seam.npy" 
mon_path = f"{data_path}/mon_seam.npy" 
# Mclean_path = f"{data_path}/mon_seam_c.npy"

parm = {
 'nt': 2500,
 'ng': 501,
 'ns': 60,
 'dt':  0.0024,
 'dg': 0.02500000037252903,
 'ds': 0.17499999701976776,
 'ot': 0.0,
 'og': 0.0,
 'os': 1.0}
 

# define the window for plotting  
# start = 100
# last =  900 

# # define the overburden window 
start = 550
last =  850 

feature_leangth = 21

start2 = 550
last2 =  1600

# %%
# 
base = np.load(base_path)
mon = np.load(mon_path)
ns,ng,nt = base.shape

mxoffset = 5 # km 


# convert to 2D 
base = base.reshape((ns*ng,nt))
mon = mon.reshape((ns*ng,nt))

# design window 
base_win = base[:,start:last]
mon_win = mon[:,start:last]

# %%
# Design filter 



nh = 21 # size of matching filter
wavc = 10 # center of matching filter

# Estimate matching filter from base to mon
Cop = VStack([MatrixMult(convmtx(base_win[iy], nh)[wavc:-nh+wavc+1]) for iy in range(base_win.shape[0])])
hmatch = Cop / mon_win.ravel()

# Apply the matching filter to base to get mon
mon_win_pred = (Cop @ hmatch).reshape(mon_win.shape)

# %% [markdown]
# ## Apply on the reservoir part

# %%
# define the reservoir from the trace 

base_win2 = base[:,start2:last2]
mon_win2 = mon[:,start2:last2]   

# Estimate matching filter from base to mon
Cop = VStack([MatrixMult(convmtx(base_win2[iy], nh)[wavc:-nh+wavc+1]) for iy in range(base_win2.shape[0])])


# Apply the matching filter to base to get mon
mon_win_pred2 = (Cop @ hmatch).reshape(mon_win2.shape)

# %%
#Convert back to 3D 

B=base_win2.reshape((ns,ng,last2-start2))
M=mon_win2.reshape((ns,ng,last2-start2))
Pr = mon_win_pred2.reshape((ns,ng,last2-start2))


# Take few shots as in the inference notebook 
B = B[40:90:10,]
M = M[40:90:10,]
Pr = Pr[40:90:10,]
ns,ng,nt_ = B.shape

# %%
''' Shot differeces plots ''' 
import matplotlib
from mpl_toolkits.axes_grid1 import make_axes_locatable


# Shot plotting 

# matplotlib.rc('image', cmap='gray')    
matplotlib.rc('image', cmap='seismic') 
font = {
'weight' : 'bold',
'size'   : 12}
matplotlib.rc('font', **font)
matplotlib.rcParams.update({'font.size': 12})
dt = 0.002
vmax = 3e-6
vmin = -vmax
# vmax = .15
# vmin = -.15
# vmin, vmax = np.percentile((Mclean-base).T,[2,98])


ncols=5
#-----------------------------------------------------------

fig, ax = plt.subplots(1,ncols,figsize=(16,5))
for i in range (ncols):
    im = ax[i].imshow(M[i].T - (Pr[i]-Pr[i].mean(axis=1, keepdims=True)).T ,vmin=vmin,vmax=vmax,extent=[0,2000,last*dt,start*dt])
    ax[i].axis("tight")
    ax[i].set_ylabel("Time(s)",fontsize=16,fontweight='bold')
    ax[i].axes.xaxis.set_visible(False)
#     ax[i].set_title(f"NRMS jkjkj \n test",fontsize=18)

    divider = make_axes_locatable(ax[i])
    cax = divider.append_axes('right', size='5%', pad=0.05)
    fig.colorbar(im, cax=cax, orientation='vertical')
fig.tight_layout(pad=1.0)
fig.savefig('./Fig/MF_n_diff', bbox_inches='tight')

#-----------------------------------------------------------

fig, ax = plt.subplots(1,ncols,figsize=(16,5))
for i in range (ncols):
    im = ax[i].imshow(M[i].T - B[i].T ,vmin=vmin,vmax=vmax,extent=[0,2000,last*dt,start*dt])
    ax[i].axis("tight")
    ax[i].set_ylabel("Time(s)",fontsize=16,fontweight='bold')
    ax[i].axes.xaxis.set_visible(False)
    divider = make_axes_locatable(ax[i])
    cax = divider.append_axes('right', size='5%', pad=0.05)
    fig.colorbar(im, cax=cax, orientation='vertical')
fig.tight_layout(pad=1.0)
# fig.savefig('./Fig/before_diff', bbox_inches='tight')

#-----------------------------------------------------------

# fig, ax = plt.subplots(1,ncols,figsize=(16,5))
# for i in range (ncols):
#     im = ax[i].imshow(Mc[i].T - B[i].T ,vmin=vmin,vmax=vmax,extent=[0,2000,last*dt,start*dt])
#     ax[i].axis("tight")
#     ax[i].set_ylabel("Time(s)",fontsize=16,fontweight='bold')
#     ax[i].axes.xaxis.set_visible(False)
#     divider = make_axes_locatable(ax[i])
#     cax = divider.append_axes('right', size='5%', pad=0.05)
#     fig.colorbar(im, cax=cax, orientation='vertical')
# fig.tight_layout(pad=1.0)
# fig.savefig('./Fig/tarfet_diff', bbox_inches='tight')

#-----------------------------------------------------------
fig, ax = plt.subplots(1,ncols,figsize=(16,5))
for i in range (ncols):
    im = ax[i].imshow((Pr[i]-Pr[i].mean(axis=1, keepdims=True)).T ,vmin=vmin,vmax=vmax,extent=[0,2000,last*dt,start*dt])
    ax[i].axis("tight")
    ax[i].set_ylabel("Time(s)",fontsize=16,fontweight='bold')
    ax[i].axes.xaxis.set_visible(False)
    divider = make_axes_locatable(ax[i])
    cax = divider.append_axes('right', size='5%', pad=0.05)
    fig.colorbar(im, cax=cax, orientation='vertical')
fig.tight_layout(pad=1.0)
fig.savefig('./Fig/MF_n_mon', bbox_inches='tight')


#-----------------------------------------------------------

fig, ax = plt.subplots(1,ncols,figsize=(16,5))
for i in range (ncols):
    im = ax[i].imshow(M[i].T ,vmin=vmin,vmax=vmax,extent=[0,2000,last*dt,start*dt])
    ax[i].axis("tight")
    ax[i].set_ylabel("Time(s)",fontsize=16,fontweight='bold')
    ax[i].axes.xaxis.set_visible(False)
    divider = make_axes_locatable(ax[i])
    cax = divider.append_axes('right', size='5%', pad=0.05)
    fig.colorbar(im, cax=cax, orientation='vertical')
fig.tight_layout(pad=1.0)
# fig.savefig('./Fig/mon', bbox_inches='tight')

# %%
base_win2.shape
# Out:
# (73080, 450)
